# %%
import pandas as pd

# %%
df = pd.read_json('data/song_data/A/B/C/TRABCEI128F424C983.json', lines= True)

# %%
df
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  ARJIE2Y1187B994AB7              NaN                               NaN
#
#    artist_name   duration  num_songs             song_id                title  \
# 0  Line Renaud  152.92036          1  SOUPIRU12A6D4FA1E1  Der Kleine Dompfaff
#
#    year
# 0     0

# %%
df2= pd.read_json('data/song_data/A/A/B/TRAABJL12903CDCF1A.json', lines= True)

# %%
df2
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  ARHHO3O1187B989413              NaN                               NaN
#
#   artist_name   duration  num_songs             song_id           title  year
# 0   Bob Azzam  191.84281          1  SORAMLE12AB017C8B0  Auguri Cha Cha     0

# %%
df2= pd.read_json('data/log_data/2018/11/2018-11-12-events.json', lines= True)

# %%
df2.loc[:,'userAgent'][0]
# Out:
# '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'

# %%
df2
# Out:
#                                                 artist        auth  \
# 0                                                 None   Logged In
# 1                                             Pavement   Logged In
# 2    Barry Tuckwell/Academy of St Martin-in-the-Fie...   Logged In
# 3                                           Gary Allan   Logged In
# 4                                                 None   Logged In
# 5                                   Charttraxx Karaoke   Logged In
# 6                                       The Libertines   Logged In
# 7                              Huey Lewis And The News   Logged In
# 8                              JOSEF LOCKE & ORCHESTRA   Logged In
# 9                                                Train   Logged In
# 10                                         Blind Pilot   Logged In
# 11                                             Anjulie   Logged In
# 12                                   59 Times the Pain   Logged In
# ...
